# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwarya-ps-kumbla/MST_Aish_practice_problems_01/blob/main/project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cloning folders,files and dataset from https://github.com/deepak-dgj270/LPRNet_PyTorch
# !git clone https://github.com/deepak-dgj270/LPRNet_PyTorch
# Out:
# fatal: destination path 'LPRNet_PyTorch' already exists and is not an empty directory.

# %%
#training and tesing. evaluating accuracy in each iteration.
# !python /content/LPRNet_PyTorch/train_LPRNet.py
# Out:
# Successful to build network!
# initial net weights successful!
# Listing files in directory: /content/LPRNet_PyTorch/dataset/train
# ['MH01AX7656_45.png', 'DL2CAN4832_15.png', 'DLICP6078_76.png', 'HR26BE1394_37.png', 'DL2CAH5398_13.png', 'AP29AJ8241_12.png', 'AP28DD1684_7.png', 'KL02AD6790_44.png', 'AP29AJ1626_9.png', 'AP04Q4949_71.png']
#
# Train Accuracy
#
# Listing files in directory: /content/LPRNet_PyTorch/dataset/test
# ['MH46N2154_61.png', 'MH48A6131_63.png', 'TN02AB6833_67.png', 'TN20CX4108_69.png', 'TN02AB6833_68.png', 'MH43AN2671_54.png']
#
# Train Accuracy
#
# 10
# Image name: AP04Q4949, Label: [10, 23, 0, 4, 24, 4, 9, 4, 9, 36], Num Plate: AP04Q4949
# Accuracy[Tp:Tn]: 100.0 [1:0]
# Image name: MH01AX7656, Label: [21, 17, 0, 1, 10, 31, 7, 6, 5, 6], Num Plate: MH01AX7656
# Accuracy[Tp:Tn]: 100.0 [1:0]
# Image name: AP28DD1684, Label: [10, 23, 2, 8, 13, 13, 1, 6, 8, 4], Num Plate: AP28DD1684
# Accuracy[Tp:Tn]: 100.0 [1:0]
# ...

# %% [markdown]
# The accuracy of the LPRNet model is 100%.The system is trained well and able to recognize all the number plate characters in test images.
